# %%
import cv2
import numpy as np
import os

def get_imlist(path):
    """    Returns a list of filenames for
        all jpg images in a directory. """
    return [os.path.join(path,f) for f in os.listdir(path) if f.endswith('.jpg')]
imgList = get_imlist('C:/Users/LCW/Desktop')
#imgName = os.path.split(imgList[i])[1]


for i, imgPath in enumerate(imgList):
    im = cv2.imread(imgPath,cv2.IMREAD_GRAYSCALE )
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    #try:
    resized_image = cv2.resize(im, (300, 300)) 
    #except:
    #    continue
    cv2.imwrite("C:/Users/LCW/Desktop/"+os.path.split(imgList[i])[1],resized_image)

# %%
import cv2
import numpy as np
# %matplotlib inline
import os

def get_imlist(path):
    """    Returns a list of filenames for
        all jpg images in a directory. """
    return [os.path.join(path,f) for f in os.listdir(path) if f.endswith('.jpg')]
imgList = get_imlist('C:/Users/LCW/Desktop/Pic')
#imgName = os.path.split(imgList[i])[1]


for i, imgPath in enumerate(imgList):
    print imgPath.split('\\')[1].split('.')[0]
# Out:
# AlmaTedema005
# AlmaTedema006
# AlmaTedema021
# AlmaTedema023
# AlmaTedema024
# AlmaTedema029
# Angelico001
# Angelico002
# Angelico004
# Angelico005
# Angelico006
# Angelico009
# Angelico010
# Angelico025
# Angelico028
# Bellini002
# Bellini004
# Bellini005
# Bellini006
# Bellini007
# Bellini010
# Bellini011
# Bellini033
# Bellini034
# Bierstadt001
# Bierstadt002
# Blake009
# Blake022
# Blake031
# Blake052
# Blake058
# Boccioni003
# Bonnard015
# Bonnard017
# Bonnard039
# Bonnard050
# Bonnard051
# Bonnard052
# Bonnard072
# Bosch001
# Bosch005
# Bosch009
# Bosch010
# Bosch013
# Bosch021
# Bosch022
# Bosch024
# Bosch026
# Botticelli002
# Botticelli003
# Botticelli004
# Botticelli005
# Botticelli007
# Botticelli008
# Botticelli014
# Botticelli015
# Botticelli019
# Botticelli029
# Botticelli031
# Botticelli037
# Boucher001
# Boucher002
# Boucher003
# Boucher004
# Boucher006
# Boucher007
# Boucher017
# Boucher021
# Boucher026
# Boucher028
# Boucher031
# Boucher033
# Boucher034
# ...
